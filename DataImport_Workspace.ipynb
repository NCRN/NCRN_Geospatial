# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/DC_shapefile_wetlands.zip'


def bar_custom(current, total, width=80):
  print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))
  
wget.download(url, bar=bar_custom)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a3c750615db> in <module>
#       5   print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))
#       6
# ----> 7 wget.download(url, bar=bar_custom)
#
# NameError: name 'wget' is not defined

# %%
import wget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-381d77ba2736> in <module>
# ----> 1 import wget
#
# ModuleNotFoundError: No module named 'wget'

# %%
import wget

# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/DC_shapefile_wetlands.zip'

def bar_custom(current, total, width=80):
  print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))
  
wget.download(url, bar=bar_custom)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# ...

# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/DC_shapefile_wetlands.zip'

# %%
def bar_custom(current, total, width=80):
  print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))

# %%
wget.download(url, bar=bar_custom)
# Out:
# Downloading: 0% [0 / 1287776] bytes
# Downloading: 0% [8192 / 1287776] bytes
# Downloading: 1% [16384 / 1287776] bytes
# Downloading: 1% [24576 / 1287776] bytes
# Downloading: 2% [32768 / 1287776] bytes
# Downloading: 3% [40960 / 1287776] bytes
# Downloading: 3% [49152 / 1287776] bytes
# Downloading: 4% [57344 / 1287776] bytes
# Downloading: 5% [65536 / 1287776] bytes
# Downloading: 5% [73728 / 1287776] bytes
# Downloading: 6% [81920 / 1287776] bytes
# Downloading: 6% [90112 / 1287776] bytes
# Downloading: 7% [98304 / 1287776] bytes
# Downloading: 8% [106496 / 1287776] bytes
# Downloading: 8% [114688 / 1287776] bytes
# Downloading: 9% [122880 / 1287776] bytes
# Downloading: 10% [131072 / 1287776] bytes
# Downloading: 10% [139264 / 1287776] bytes
# Downloading: 11% [147456 / 1287776] bytes
# Downloading: 12% [155648 / 1287776] bytes
# Downloading: 12% [163840 / 1287776] bytes
# Downloading: 13% [172032 / 1287776] bytes
# Downloading: 13% [180224 / 1287776] bytes
# ...

# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/MD_shapefile_wetlands.zip'

# %%
wget.download(url, bar=bar_custom)
# Out:
# Downloading: 0% [0 / 199466551] bytes
# Downloading: 0% [8192 / 199466551] bytes
# Downloading: 0% [16384 / 199466551] bytes
# Downloading: 0% [24576 / 199466551] bytes
# Downloading: 0% [32768 / 199466551] bytes
# Downloading: 0% [40960 / 199466551] bytes
# Downloading: 0% [49152 / 199466551] bytes
# Downloading: 0% [57344 / 199466551] bytes
# Downloading: 0% [65536 / 199466551] bytes
# Downloading: 0% [73728 / 199466551] bytes
# Downloading: 0% [81920 / 199466551] bytes
# Downloading: 0% [90112 / 199466551] bytes
# Downloading: 0% [98304 / 199466551] bytes
# Downloading: 0% [106496 / 199466551] bytes
# Downloading: 0% [114688 / 199466551] bytes
# Downloading: 0% [122880 / 199466551] bytes
# Downloading: 0% [131072 / 199466551] bytes
# Downloading: 0% [139264 / 199466551] bytes
# Downloading: 0% [147456 / 199466551] bytes
# Downloading: 0% [155648 / 199466551] bytes
# Downloading: 0% [163840 / 199466551] bytes
# Downloading: 0% [172032 / 199466551] bytes
# ...

# %%
url = r'http://landsnet.nps.gov/tractsnet/public_release_data/nps_boundary.zip'

# %%
wget.download(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-14-e92463be8f05> in <module>
# ----> 1 wget.download(url)
#
# ~\AppData\Roaming\Python\Python39\site-packages\wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     237     url_type, path = _splittype(url)
#     238
# --> 239     with contextlib.closing(urlopen(url, data)) as fp:
#     240         headers = fp.info()
#     241
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
# ...

# %%
wget.download(url, bar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6e6d7ffe30af> in <module>
# ----> 1 wget.download(url, bar)
#
# NameError: name 'bar' is not defined

# %%
wget.download(url, bar=bar_thermometer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-7ca8b7c5cab0> in <module>
# ----> 1 wget.download(url, bar=bar_thermometer)
#
# NameError: name 'bar_thermometer' is not defined

# %%
wget.download(url, bar=bar_custom)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-17-adabe9ef60e8> in <module>
# ----> 1 wget.download(url, bar=bar_custom)
#
# ~\AppData\Roaming\Python\Python39\site-packages\wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     237     url_type, path = _splittype(url)
#     238
# --> 239     with contextlib.closing(urlopen(url, data)) as fp:
#     240         headers = fp.info()
#     241
#
# ...

# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/WV_shapefile_wetlands.zip'

# %%
wget.download(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e92463be8f05> in <module>
# ----> 1 wget.download(url)
#
# NameError: name 'wget' is not defined

# %%
wget.download(url, bar=bar_custom)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-adabe9ef60e8> in <module>
# ----> 1 wget.download(url, bar=bar_custom)
#
# NameError: name 'wget' is not defined

# %%
import wget

# %%
wget.download(url)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# <ipython-input-5-e92463be8f05> in <module>
# ----> 1 wget.download(url)
#
# ~\AppData\Roaming\Python\Python39\site-packages\wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     237     url_type, path = _splittype(url)
#     238
# --> 239     with contextlib.closing(urlopen(url, data)) as fp:
#     240         headers = fp.info()
#     241
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
# ...

# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/DC_shapefile_wetlands.zip'


def bar_custom(current, total, width=80):
  print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))
  
wget.download(url, bar=bar_custom)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# ...

# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/DC_shapefile_wetlands.zip'

# %%
def bar_custom(current, total, width=80):
  print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))

# %%
wget.download(url, bar=bar_custom)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# ...

# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/DC_shapefile_wetlands.zip'

# %%
import wget

# %%
url = r'https://www.fws.gov/wetlands/Data/State-Downloads/DC_shapefile_wetlands.zip'

# %%
wget.download(url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# ...
